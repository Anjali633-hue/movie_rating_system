# %% [markdown]
# **Movie Rating System Project**

# %% [markdown]
# Load the 'content/movies.csv' dataset into a DataFrame and perform the following tasks:
# 1. What are the most common movie genres?
# 2. Which studios produce the highest number of movies?
# 3. What is the distribution of movie ratings?
# 4. Which movies have the highest profitability?
# 5. What is the relationship between ratings and profitability?
# 6. Which movies have the highest worldwide gross earnings?
# 7. How does the rating distribution vary across different genres?

# %% [markdown]
# **Step-1:** Importing the required libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step-2:** Loading the CSV data into a DataFrame.

# %%
data=pd.read_csv(r"C:\Users\Admin\Downloads\movies_dataset.csv")
data
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     rating  Profitability Worldwide Gross  Year
# 0        8       1.747542         $41.94   2008
# ...

# %% [markdown]
# **Display the first few rows of the dataset**

# %%
data.head()
# Out:
#                                  Film    Genre            Lead Studio  rating  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company       8
# 1                     Youth in Revolt   Comedy  The Weinstein Company       4
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent       9
# 3                        When in Rome   Comedy                 Disney       5
# 4               What Happens in Vegas   Comedy                    Fox       6
#
#    Profitability Worldwide Gross  Year
# 0       1.747542         $41.94   2008
# 1       1.090000         $19.62   2010
# 2       1.211818         $26.66   2010
# 3       0.000000         $43.04   2010
# 4       6.267647        $219.37   2008

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'rating', 'Profitability',
#        'Worldwide Gross', 'Year'],
#       dtype='object')

# %% [markdown]
# **Basic information about the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             77 non-null     object
#  1   Genre            77 non-null     object
#  2   Lead Studio      77 non-null     object
#  3   rating           77 non-null     int64
#  4   Profitability    77 non-null     float64
#  5   Worldwide Gross  77 non-null     object
#  6   Year             77 non-null     int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 4.3+ KB

# %% [markdown]
# **Get summary statistics**

# %%
data.describe()
# Out:
#           rating  Profitability         Year
# count  77.000000      77.000000    77.000000
# mean    5.701299       4.599483  2009.077922
# std     2.870288       8.031990     1.354974
# min     1.000000       0.000000  2007.000000
# 25%     3.000000       1.751351  2008.000000
# 50%     6.000000       2.642353  2009.000000
# 75%     8.000000       5.103117  2010.000000
# max    10.000000      66.934000  2011.000000

# %% [markdown]
# **step-3:** Identifying the null values

# %%
data.isnull().sum()
# Out:
# Film               0
# Genre              0
# Lead Studio        0
# rating             0
# Profitability      0
# Worldwide Gross    0
# Year               0
# dtype: int64

# %% [markdown]
# **lead studio column convert into array**

# %%
arr=data['Lead Studio'].unique()
arr
# Out:
# array(['The Weinstein Company', 'Independent', 'Disney', 'Fox',
#        '20th Century Fox', 'Warner Bros.', 'Summit', 'Paramount', 'CBS',
#        'New Line', 'Sony', 'Universal', 'Lionsgate'], dtype=object)

# %% [markdown]
# **Step-4** What are the most common movie genres?

# %%
genre_counts = data['Genre'].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(x=genre_counts.index, y=genre_counts.values, palette="viridis")
plt.xticks(rotation=45)
plt.xlabel("Genres")
plt.ylabel("Number of Movies")
plt.title("Most Common Movie Genres")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6464\3374995677.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_counts.index, y=genre_counts.values, palette="viridis")

# %% [markdown]
# **Step-5** Which studios produce the highest number of movies?

# %%
studio_counts = data['Lead Studio'].value_counts().head(10)  # Top 10 studios
plt.figure(figsize=(10,5))
sns.barplot(x=studio_counts.index, y=studio_counts.values, palette="magma")
plt.xticks(rotation=45)
plt.xlabel("Studios")
plt.ylabel("Number of Movies")
plt.title("Top 10 Studios Producing the Most Movies")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6464\117394310.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=studio_counts.index, y=studio_counts.values, palette="magma")

# %% [markdown]
# **Step-6** What is the distribution of movie ratings?

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['rating'], bins=10, kde=True, color="blue")
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.title("Distribution of Movie Ratings")
plt.show()

# %% [markdown]
# **Step-7** Which movies have the highest profitability?

# %%
data['Profitability'].value_counts()
plt.figure(figsize=(6,5))
sns.countplot(x='rating',order=data['rating'].value_counts().index[0:10],data=data)
plt.xlabel("rating")
plt.ylabel("count")
plt.title("Distribution of Movie Ratings")
plt.show()

# %% [markdown]
# **Step-8** highest rating of two column

# %%
plt.figure(figsize=(6,5))
sns.barplot(y=data['Film'].head(20),x=data['rating'].head(20),data=data)
plt.xlabel('rating')
plt.ylabel('Film')
plt.title("In top 20 movies which movie gains highest rating")
plt.show()
